# %%
import pandas as pd
import os 

excel_filename = '0(u_new_4,cab=0.04,k=-20,a=1).xlsx'

# 构建相对路径
relative_path_to_data = os.path.join( '..','data', excel_filename)

print(f"当前工作目录 (Jupyter Kernel CWD): {os.getcwd()}")
print(f"尝试读取文件的绝对路径: {os.path.abspath(relative_path_to_data)}")
# Out:
# 当前工作目录 (Jupyter Kernel CWD): D:\SoftManiSim-spy\spy_code\notebooks
# 尝试读取文件的绝对路径: D:\SoftManiSim-spy\spy_code\data\0(u_new_4,cab=0.04,k=-20,a=1).xlsx

# %%
df = pd.read_excel(relative_path_to_data)
print("数据加载成功！")
# Out:
# 数据加载成功！

# %%
from IPython.display import Image

model_subfolder_name = 'lstm_residual_model_true'
image_filename1 = 'comparison_error_boxplot_final.png'

relative_path_to_image = os.path.join('..', 'model', model_subfolder_name, image_filename1)

print(f"当前工作目录 (Jupyter Kernel CWD): {os.getcwd()}")
print(f"尝试加载图片的绝对路径: {os.path.abspath(relative_path_to_image)}")
# Out:
# 当前工作目录 (Jupyter Kernel CWD): D:\SoftManiSim-spy\spy_code\notebooks
# 尝试加载图片的绝对路径: D:\SoftManiSim-spy\spy_code\model\lstm_residual_model_true\comparison_error_boxplot_final.png

# %%
display(Image(filename=relative_path_to_image, width=600))

# %% [markdown]
# ---
# 该图通过误差箱线图直观对比了纯物理仿真（基于Cosserat杆理论）与引入LSTM+Attention神经网络进行残差补偿后的混合模型在机器人末端定位精度上的表现。结果清晰显示，加入神经网络修正后，模型在X、Y、Z三轴的绝对误差及综合三维位置误差均显著降低，且误差分布更为集中，表明混合模型能有效提升仿真精度和稳定性。
# ---

# %%
model_subfolder_name = 'transformer_residual_model'
image_filename2 = 'comparison_physics_vs_transformer.png'
#image_filename2 = 'comparison_lstm_vs_transformer.png'

relative_path_to_image2 = os.path.join('..', 'model', model_subfolder_name, image_filename2)

print(f"当前工作目录 (Jupyter Kernel CWD): {os.getcwd()}")
print(f"尝试加载图片的绝对路径: {os.path.abspath(relative_path_to_image)}")
display(Image(filename=relative_path_to_image2, width=600))
# Out:
# 当前工作目录 (Jupyter Kernel CWD): D:\SoftManiSim-spy\spy_code\notebooks
# 尝试加载图片的绝对路径: D:\SoftManiSim-spy\spy_code\model\transformer_residual_model\comparison_physics_vs_transformer.png

# %% [markdown]
# ---
# 该图通过误差箱线图直观对比了纯物理仿真（基于Cosserat杆理论）与引入Transformer神经网络进行残差补偿后的混合模型在机器人末端定位精度上的表现。结果清晰显示，加入神经网络修正后，模型在X、Y、Z三轴的绝对误差及综合三维位置误差均显著降低，且误差分布更为集中，表明混合模型能有效提升仿真精度和稳定性。
# ---

# %%
model_subfolder_name = 'transformer_residual_model'
image_filename3 = 'comparison_lstm_vs_transformer.png'

relative_path_to_image3 = os.path.join('..', 'model', model_subfolder_name, image_filename3)

print(f"当前工作目录 (Jupyter Kernel CWD): {os.getcwd()}")
print(f"尝试加载图片的绝对路径: {os.path.abspath(relative_path_to_image)}")
display(Image(filename=relative_path_to_image3, width=600))
# Out:
# 当前工作目录 (Jupyter Kernel CWD): D:\SoftManiSim-spy\spy_code\notebooks
# 尝试加载图片的绝对路径: D:\SoftManiSim-spy\spy_code\model\transformer_residual_model\comparison_physics_vs_transformer.png

# %% [markdown]
# ---
# 该图通过误差箱线图直观对比了引入LSTM+Attention引入Transformer神经网络进行残差补偿后的混合模型在机器人末端定位精度上的表现。结果清晰显示，加入Transformer修正后，模型在X与Z轴的绝对误差误差均降低，但在Y轴与三维位置误差表现却变差了。
# ---
